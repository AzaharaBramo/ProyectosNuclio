# %% [markdown]
# <div align="center">
# <h1 style="color:#2c3e50;">📊 Proyecto MySQL</h1>
# <h2 style="color:#34495e;">Análisis de Base de Datos</h2>
#
#
#
# **Nuclio Digital School**
# *Módulo 5: My SQL*
#
# ---
#
# <span style="color:#3498db"> **Autor:** Azahara Bravo Montalbán
#
# <span style="color:#3498db">**Fecha:** 20 de Junio, 2025
# <span style="color:#3498db">**Versión:** 1.0
#
# </div>

# %% [markdown]
# # **ENUNCIADO**

# %% [markdown]
# <span style="color:#3498db">Trabajas en una agencia que se dedica a organizar viajes a personas, tu cargo específicamente es analista de datos del área de clientes VIP.
#
# <span style="color:#3498db">Ha llegado a la agencia un cantante famoso, conocido en España, que desea que le ubiquéis un buen alojamiento que le permita disfrutar del sol para sus próximas vacaciones de verano que serán a finales del mes de julio del 2025.
#
# <span style="color:#3498db">Este cliente quiere descansar porque necesita prepararse para una gira de conciertos que dará en septiembre y por ahora quiere alejarse del foco mediático todo lo que pueda durante sus vacaciones, no le gustaría llamar la atención durante esos días ya que estará con sus 2 padres, sus 2 hermanos pequeños, su novia y los padres de su novia.
#
# <span style="color:#3498db">El cliente no tiene claro el destino al que quiere ir, solo sabe que tiene que ser en alguna playa. Tu trabajo será encontrar la propiedad en la que el cliente y su familia se alojarán durante sus vacaciones de verano teniendo en cuenta las exigencias del cliente.

# %% [markdown]
# # **PRIMERA PARTE**

# %% [markdown]
# <span style="color:#3498db"> Primer paso: crear la query de cada uno de las exigencias del cliente. Se debe crear una query para cada punto. (7 queries en total)

# %% [markdown]
# <span style="color:#3498db"> - El cliente exige terraza y aire acondicionado, pero no quiere piscina.

# %% [markdown]
# <span style="color:#3498db"> - No se alojará en estudios que no tengan salón ni en propiedades con solo un baño

# %% [markdown]
# <span style="color:#3498db"> - La propiedad debe tener como mínimo 80m2

# %% [markdown]
# <span style="color:#3498db"> - Como el cliente odia el ruido, no quiere alojarse en propiedades a menos de 1 km de una estación de metro ni a menos de 2 km del centro.

# %% [markdown]
# <span style="color:#3498db"> - El rango permitido por el cliente para pagar es entre 1.500€ y 2.000€ la noche.

# %% [markdown]
# <span style="color:#3498db"> - Como en anteriores ocasiones ha tenido problemas de intentos de estafas con otras agencias, el cliente pide que el % de reserva no sea muy alto, pero tampoco tan bajo (porque le genera inseguridad) por lo que propone un 25%

# %% [markdown]
# <span style="color:#3498db"> - Quiere que el alojamiento tenga más de 4,5 puntos de confianza y que la agencia que lo lleva tenga más de 4 puntos

# %%
# !pip install sqlalchemy
# !pip install mysql-connector-python

# %%
from sqlalchemy import create_engine
import sqlalchemy
import mysql.connector as mysql
import pandas as pd

# %% [markdown]
# **Creamos la conexión**

# %%
# Parámetros de conexión
user     = 'root'
password = '13Data2025#'
#db = ''
sqlServer = 'localhost' # debería ser IP o DNS (Domain Name System) del servidor de la base de datos

# Creamos string de conexión
connStr = "mysql+mysqlconnector://" + user + ":" + password + "@" + sqlServer # +  "/"  + db

# print de string de conexión
print (connStr)

# Conectamos con el servidor
conn = create_engine(connStr).connect()
# Out:
# mysql+mysqlconnector://root:13Data2025#@localhost

# %% [markdown]
# **CREAMOS LA BASE DE DATOS**

# %%
# Crea una BD con nombre ENTREGABLE
sSQL = "CREATE DATABASE ENTREGABLE"
conn.execute(sSQL)

# %%
# Cerrar conexión anterior y conectar a la base de datos ENTREGABLE
conn.close()

# Nueva conexión a la base de datos del entregable
db = 'ENTREGABLE'
connStr = "mysql+mysqlconnector://" + user + ":" + password + "@" + sqlServer + "/" + db
print(connStr)

# Conectar a la base de datos ENTREGABLE
conn = create_engine(connStr).connect()
print("✅ Conectado a la base de datos ENTREGABLE")
# Out:
# mysql+mysqlconnector://root:13Data2025#@localhost/ENTREGABLE
# ✅ Conectado a la base de datos ENTREGABLE

# %% [markdown]
# **ANALIZO LAS TABLAS DESDE PANDAS**

# %%
# Leer los archivos Excel

# Leer archivo ALOJAMIENTO
df_alojamiento = pd.read_excel('ALOJAMIENTO.xlsx')
print("📊 TABLA ALOJAMIENTO:")
print(f"Filas: {len(df_alojamiento)}, Columnas: {len(df_alojamiento.columns)}")
print("Columnas:", list(df_alojamiento.columns))
print("\nPrimeras 5 filas:")
print(df_alojamiento.head(5))
# Out:
# 📊 TABLA ALOJAMIENTO:
# Filas: 20, Columnas: 9
# Columnas: ['CODIGO_ALOJAMIENTO', 'NOMBRE', 'CANT_BANYOS', 'CANT_HAB', 'SALON', 'TERRAZA', 'AIREC_ACOND', 'PISCINA', 'SUPERFICIE']
#
# Primeras 5 filas:
#   CODIGO_ALOJAMIENTO                    NOMBRE  CANT_BANYOS  CANT_HAB SALON  \
# 0            ALOJ001         Villa Sol del Mar            2         3    SI
# 1            ALOJ002  Apartamento Las Palmeras            1         2    SI
# 2            ALOJ003         Cabaña El Refugio            1         1    NO
# 3            ALOJ004     Piso Centro Histórico            2         3    SI
# 4            ALOJ005      Estudio Playa Blanca            1         1    NO
#
#   TERRAZA AIREC_ACOND PISCINA  SUPERFICIE
# 0      SI          SI      SI         120
# 1      NO          SI      NO          75
# 2      SI          NO      NO          45
# 3      SI          SI      NO          90
# 4      NO          SI      NO          40

# %%
# Leer archivo PRECIO
df_precio = pd.read_excel('PRECIO.xlsx')
print("📊 TABLA PRECIO:")
print(f"Filas: {len(df_precio)}, Columnas: {len(df_precio.columns)}")
print("Columnas:", list(df_precio.columns))
print("\nPrimeras 5 filas:")
print(df_precio.head(5))
# Out:
# 📊 TABLA PRECIO:
# Filas: 20, Columnas: 4
# Columnas: ['CODIGO_ALOJAMIENTO', 'PRECIO_ALQUILER', 'RESERVA', 'PORCENTAJE_RESERVA']
#
# Primeras 5 filas:
#   CODIGO_ALOJAMIENTO  PRECIO_ALQUILER RESERVA  PORCENTAJE_RESERVA
# 0            ALOJ001             1800      SI                 100
# 1            ALOJ002              780      SI                  25
# 2            ALOJ003              800      NO                   0
# 3            ALOJ004             1600      SI                  25
# 4            ALOJ005              900      NO                   0

# %%
# Leer archivo PUNTUACION
df_puntuacion = pd.read_excel('PUNTUACION.xlsx')
print("📊 TABLA PUNTUACION:")
print(f"Filas: {len(df_puntuacion)}, Columnas: {len(df_puntuacion.columns)}")
print("Columnas:", list(df_puntuacion.columns))
print("\nPrimeras 5 filas:")
print(df_puntuacion.head(5))
# Out:
# 📊 TABLA PUNTUACION:
# Filas: 20, Columnas: 4
# Columnas: ['CODIGO_ALOJAMIENTO', 'PUNTOS', 'AGENCIA', 'PUNTOS_AGENCIA']
#
# Primeras 5 filas:
#   CODIGO_ALOJAMIENTO  PUNTOS       AGENCIA  PUNTOS_AGENCIA
# 0            ALOJ001     5.0    GlobalHome             4.4
# 1            ALOJ002     4.2    AndesRenta             4.1
# 2            ALOJ003     4.1  AlquilaFacil             4.0
# 3            ALOJ004     4.6    CaribeRent             4.6
# 4            ALOJ005     4.4      RentaTop             3.8

# %%
# Leer archivo UBICACION
df_ubicacion = pd.read_excel('UBICACION.xlsx')
print("📊 TABLA UBICACION:")
print(f"Filas: {len(df_ubicacion)}, Columnas: {len(df_ubicacion.columns)}")
print("Columnas:", list(df_ubicacion.columns))
print("\nPrimeras 5 filas:")
print(df_ubicacion.head(5))
# Out:
# 📊 TABLA UBICACION:
# Filas: 20, Columnas: 5
# Columnas: ['CODIGO_ALOJAMIENTO', 'PAIS', 'CIUDAD', 'DIST_METRO', 'DIST_CENTRO']
#
# Primeras 5 filas:
#   CODIGO_ALOJAMIENTO      PAIS     CIUDAD  DIST_METRO  DIST_CENTRO
# 0            ALOJ001  Portugal      Liboa         1.0          2.0
# 1            ALOJ002    España     Madrid         0.5          0.8
# 2            ALOJ003    España  Barcelona         0.9          0.4
# 3            ALOJ004   Francia   Marsella         3.0          4.0
# 4            ALOJ005  Portugal     Oporto         4.0          3.0

# %% [markdown]
# **DESCARGAR LAS TABLAS A SQL**

# %%
# ========== CARGAR DATOS A MYSQL ==========
# (Los DataFrames ya están cargados desde el análisis anterior)

# 1. ALOJAMIENTO
print("📊 Cargando ALOJAMIENTO a MySQL...")
df_alojamiento.to_sql('ALOJAMIENTO', conn, if_exists='replace', index=False)
print("✅ Tabla ALOJAMIENTO creada y cargada")

# 2. UBICACION  
print("📊 Cargando UBICACION a MySQL...")
df_ubicacion.to_sql('UBICACION', conn, if_exists='replace', index=False)
print("✅ Tabla UBICACION creada y cargada")

# 3. PRECIO
print("📊 Cargando PRECIO a MySQL...")
df_precio.to_sql('PRECIO', conn, if_exists='replace', index=False)
print("✅ Tabla PRECIO creada y cargada")

# 4. PUNTUACION
print("📊 Cargando PUNTUACION a MySQL...")
df_puntuacion.to_sql('PUNTUACION', conn, if_exists='replace', index=False)
print("✅ Tabla PUNTUACION creada y cargada")

print("\n🎉 ¡Todas las tablas cargadas exitosamente en MySQL!")
# Out:
# 📊 Cargando ALOJAMIENTO a MySQL...
# C:\Users\Azahara\AppData\Local\Temp\ipykernel_6688\2423282733.py:6: UserWarning: The provided table name 'ALOJAMIENTO' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df_alojamiento.to_sql('ALOJAMIENTO', conn, if_exists='replace', index=False)
# C:\Users\Azahara\AppData\Local\Temp\ipykernel_6688\2423282733.py:11: UserWarning: The provided table name 'UBICACION' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df_ubicacion.to_sql('UBICACION', conn, if_exists='replace', index=False)
# ...

# %%
# Verificar tablas creadas
conn.execute("show tables").fetchall()
# Out:
# [('alojamiento',), ('precio',), ('puntuacion',), ('ubicacion',)]

# %%
# Ver cuántos datos hay en cada tabla
conn.execute("SELECT COUNT(*) FROM alojamiento;").fetchall()
# Out:
# [(20,)]

# %%
conn.execute("SELECT COUNT(*) FROM precio;").fetchall()
# Out:
# [(20,)]

# %%
conn.execute("SELECT COUNT(*) FROM puntuacion;").fetchall()
# Out:
# [(20,)]

# %%
conn.execute("SELECT COUNT(*) FROM ubicacion;").fetchall()
# Out:
# [(20,)]

# %% [markdown]
# Tal y como he visto anteriormente en el análisis de los Xlxs con python estas tablas tienen 20 alojamientos todas.

# %% [markdown]
# ## <span style="color:#3498db"> **1.EJERCICIOS PRIMERA PARTE**

# %% [markdown]
# ### <span style="color:#3498db">**1.1 QUERYS UNA A UNA**

# %% [markdown]
# **QUERY 1**

# %%
# Query 1: Terraza SI, Aire acondicionado SI, Piscina NO
query1 = "SELECT * FROM alojamiento WHERE TERRAZA = 'SI' AND AIREC_ACOND = 'SI' AND PISCINA = 'NO'"

sSQL = pd.read_sql(query1, conn)
sSQL
# Out:
#   CODIGO_ALOJAMIENTO                 NOMBRE  CANT_BANYOS  CANT_HAB SALON  \
# 0            ALOJ004  Piso Centro Histórico            2         3    SI
# 1            ALOJ010          Ático del Sol            3         3    SI
# 2            ALOJ015       Dúplex Las Rocas            3         4    SI
# 3            ALOJ018    Piso Parque Central            2         4    SI
#
#   TERRAZA AIREC_ACOND PISCINA  SUPERFICIE
# 0      SI          SI      NO          90
# 1      SI          SI      NO          88
# 2      SI          SI      NO         120
# 3      SI          SI      NO         100

# %% [markdown]
# **QUERY 2**

# %%
# Query 2: Salon SI y más de 1 baño
query2 = "SELECT * FROM alojamiento WHERE SALON = 'SI' AND CANT_BANYOS > 1"

sSQL = pd.read_sql(query2, conn)
sSQL
# Out:
#    CODIGO_ALOJAMIENTO                   NOMBRE  CANT_BANYOS  CANT_HAB SALON  \
# 0             ALOJ001        Villa Sol del Mar            2         3    SI
# 1             ALOJ004    Piso Centro Histórico            2         3    SI
# 2             ALOJ006     Chalet Vista al Lago            3         4    SI
# 3             ALOJ007  Dúplex Jardines del Sur            2         3    SI
# 4             ALOJ009     Casa Rústica Montaña            2         2    SI
# 5             ALOJ010            Ático del Sol            3         3    SI
# 6             ALOJ012           Villa Palmeras            2         3    SI
# 7             ALOJ014             Casa del Mar            3         4    SI
# 8             ALOJ015         Dúplex Las Rocas            3         4    SI
# 9             ALOJ017    Chalet Jardín Secreto            3         5    SI
# 10            ALOJ018      Piso Parque Central            2         4    SI
# ...

# %% [markdown]
# **QUERY 3**

# %%
# Query 3: Superficie mínimo 80m2
query3 = "SELECT * FROM alojamiento WHERE SUPERFICIE >= 80"

sSQL= pd.read_sql(query3, conn)
sSQL
# Out:
#    CODIGO_ALOJAMIENTO                   NOMBRE  CANT_BANYOS  CANT_HAB SALON  \
# 0             ALOJ001        Villa Sol del Mar            2         3    SI
# 1             ALOJ004    Piso Centro Histórico            2         3    SI
# 2             ALOJ006     Chalet Vista al Lago            3         4    SI
# 3             ALOJ007  Dúplex Jardines del Sur            2         3    SI
# 4             ALOJ009     Casa Rústica Montaña            2         2    SI
# 5             ALOJ010            Ático del Sol            3         3    SI
# 6             ALOJ012           Villa Palmeras            2         3    SI
# 7             ALOJ013      Apartamento Moderno            1         2    SI
# 8             ALOJ014             Casa del Mar            3         4    SI
# 9             ALOJ015         Dúplex Las Rocas            3         4    SI
# 10            ALOJ017    Chalet Jardín Secreto            3         5    SI
# ...

# %% [markdown]
# **QUERY 4**

# %%
# Query 4: Distancia metro >1km Y distancia centro >2km
query4 = "SELECT * FROM ubicacion WHERE DIST_METRO > 1 AND DIST_CENTRO > 2"

sSQL = pd.read_sql(query4, conn)
sSQL
# Out:
#   CODIGO_ALOJAMIENTO      PAIS     CIUDAD  DIST_METRO  DIST_CENTRO
# 0            ALOJ004   Francia   Marsella         3.0          4.0
# 1            ALOJ005  Portugal     Oporto         4.0          3.0
# 2            ALOJ008    España  Barcelona         2.0          3.0
# 3            ALOJ009    España     Madrid         2.0          4.0
# 4            ALOJ010    España     Bilbao         2.0          5.0
# 5            ALOJ015    España     Málaga         2.0          4.0
# 6            ALOJ018    España      Ibiza         2.0          4.0

# %% [markdown]
# **QUERY 5**

# %%
# Query 5: Precio entre 1500 y 2000 euros
query5 = "SELECT * FROM precio WHERE PRECIO_ALQUILER BETWEEN 1500 AND 2000"

sSQL = pd.read_sql(query5, conn)
sSQL
# Out:
#    CODIGO_ALOJAMIENTO  PRECIO_ALQUILER RESERVA  PORCENTAJE_RESERVA
# 0             ALOJ001             1800      SI                 100
# 1             ALOJ004             1600      SI                  25
# 2             ALOJ008             1500      SI                  25
# 3             ALOJ009             1600      SI                 100
# 4             ALOJ010             1750      SI                  25
# 5             ALOJ011             1825      NO                   0
# 6             ALOJ012             1750      NO                   0
# 7             ALOJ013             1652      NO                   0
# 8             ALOJ014             1941      NO                   0
# 9             ALOJ015             1800      SI                  25
# 10            ALOJ016             2000      SI                  30
# 11            ALOJ018             1900      SI                  25
# 12            ALOJ019             1570      NO                   0
# ...

# %% [markdown]
# **QUERY 6**

# %%
# Query 6: Porcentaje de reserva = 25%
query6 = "SELECT * FROM precio WHERE PORCENTAJE_RESERVA = 25"

sSQL = pd.read_sql(query6, conn)
sSQL
# Out:
#   CODIGO_ALOJAMIENTO  PRECIO_ALQUILER RESERVA  PORCENTAJE_RESERVA
# 0            ALOJ002              780      SI                  25
# 1            ALOJ004             1600      SI                  25
# 2            ALOJ008             1500      SI                  25
# 3            ALOJ010             1750      SI                  25
# 4            ALOJ015             1800      SI                  25
# 5            ALOJ018             1900      SI                  25

# %% [markdown]
# **QUERY 7**

# %%
# Query 7: Puntos alojamiento >4.5 Y puntos agencia >4
query7 = "SELECT * FROM puntuacion WHERE PUNTOS > 4.5 AND PUNTOS_AGENCIA > 4"

sSQL = pd.read_sql(query7, conn)
sSQL
# Out:
#    CODIGO_ALOJAMIENTO  PUNTOS            AGENCIA  PUNTOS_AGENCIA
# 0             ALOJ001     5.0         GlobalHome             4.4
# 1             ALOJ004     4.6         CaribeRent             4.6
# 2             ALOJ007     4.9       SevillaRooms             4.5
# 3             ALOJ008     4.8          ChileVive             4.3
# 4             ALOJ009     4.7         MexicoRent             4.8
# 5             ALOJ010     4.8          UYAlquila             4.9
# 6             ALOJ014     4.7        BogotaLodge             4.5
# 7             ALOJ015     4.9  EasyStay Valencia             4.7
# 8             ALOJ017     4.9         CuscoRenta             4.4
# 9             ALOJ018     4.7       MendozaRooms             4.7
# 10            ALOJ019     4.9            GDLRent             4.2
# 11            ALOJ020     4.9           VivaStay             4.9

# %% [markdown]
# ### <span style="color:#3498db"> **1.2 QUERY COMBINADA**

# %%
# ========== QUERY COMBINADA - TODOS LOS FILTROS ==========

query_final = """
SELECT 
    a.CODIGO_ALOJAMIENTO,
    a.NOMBRE,
    a.TERRAZA,
    a.AIREC_ACOND, 
    a.PISCINA,
    a.SALON,
    a.CANT_BANYOS,
    a.SUPERFICIE,
    u.PAIS,
    u.CIUDAD,
    u.DIST_METRO,
    u.DIST_CENTRO,
    p.PRECIO_ALQUILER,
    p.PORCENTAJE_RESERVA,
    pt.PUNTOS,
    pt.AGENCIA,
    pt.PUNTOS_AGENCIA
FROM alojamiento a
JOIN ubicacion u ON a.CODIGO_ALOJAMIENTO = u.CODIGO_ALOJAMIENTO
JOIN precio p ON a.CODIGO_ALOJAMIENTO = p.CODIGO_ALOJAMIENTO
JOIN puntuacion pt ON a.CODIGO_ALOJAMIENTO = pt.CODIGO_ALOJAMIENTO
WHERE a.TERRAZA = 'SI'
  AND a.AIREC_ACOND = 'SI'
  AND a.PISCINA = 'NO'
  AND a.SALON = 'SI'
  AND a.CANT_BANYOS > 1
  AND a.SUPERFICIE >= 80
  AND u.DIST_METRO > 1
  AND u.DIST_CENTRO > 2
  AND p.PRECIO_ALQUILER BETWEEN 1500 AND 2000
  AND p.PORCENTAJE_RESERVA = 25
  AND pt.PUNTOS > 4.5
  AND pt.PUNTOS_AGENCIA > 4
"""

pd.read_sql(query_final, conn)
# Out:
#   CODIGO_ALOJAMIENTO                 NOMBRE TERRAZA AIREC_ACOND PISCINA SALON  \
# 0            ALOJ004  Piso Centro Histórico      SI          SI      NO    SI
# 1            ALOJ010          Ático del Sol      SI          SI      NO    SI
# 2            ALOJ015       Dúplex Las Rocas      SI          SI      NO    SI
# 3            ALOJ018    Piso Parque Central      SI          SI      NO    SI
#
#    CANT_BANYOS  SUPERFICIE     PAIS    CIUDAD  DIST_METRO  DIST_CENTRO  \
# 0            2          90  Francia  Marsella         3.0          4.0
# 1            3          88   España    Bilbao         2.0          5.0
# 2            3         120   España    Málaga         2.0          4.0
# 3            2         100   España     Ibiza         2.0          4.0
#
#    PRECIO_ALQUILER  PORCENTAJE_RESERVA  PUNTOS            AGENCIA  \
# 0             1600                  25     4.6         CaribeRent
# 1             1750                  25     4.8          UYAlquila
# ...

# %% [markdown]
# ### <span style="color:#3498db"> **1.3 RECOMENDACIÓN**

# %% [markdown]
#  <span style="color:#3498db"> Como habéis visto, tenemos 4 propiedades que cumplen con todas las exigencias de nuestro cliente, ahora bien, desde tu punto de vista, haciendo un análisis de los datos del cliente y de todas sus exigencias ¿Cuál de estos 4 alojamientos le recomendarías y por qué?

# %% [markdown]
# <div style="background-color:#f8f9fa; padding:10px; border-left:4px solid #3498db; margin:10px 0; color:#2c3e50; font-weight:500;">
# <strong>💡 Nota importante:</strong> DEBO SABER CUÁNTAS HABITACIONES HAY PARA PODER DECIDIR YA QUE SON 8 PERSONAS
# </div>

# %%
# ========== QUERY COMBINADA - INCLUYENDO HABITACIONES ==========

query_final = """
SELECT 
    a.CODIGO_ALOJAMIENTO,
    a.NOMBRE,
    a.CANT_HAB,
    a.CANT_BANYOS,
    a.SUPERFICIE,
    a.TERRAZA,
    a.AIREC_ACOND, 
    a.PISCINA,
    a.SALON,
    u.PAIS,
    u.CIUDAD,
    u.DIST_METRO,
    u.DIST_CENTRO,
    p.PRECIO_ALQUILER,
    p.PORCENTAJE_RESERVA,
    pt.PUNTOS,
    pt.AGENCIA,
    pt.PUNTOS_AGENCIA
FROM alojamiento a
JOIN ubicacion u ON a.CODIGO_ALOJAMIENTO = u.CODIGO_ALOJAMIENTO
JOIN precio p ON a.CODIGO_ALOJAMIENTO = p.CODIGO_ALOJAMIENTO
JOIN puntuacion pt ON a.CODIGO_ALOJAMIENTO = pt.CODIGO_ALOJAMIENTO
WHERE a.TERRAZA = 'SI'
  AND a.AIREC_ACOND = 'SI'
  AND a.PISCINA = 'NO'
  AND a.SALON = 'SI'
  AND a.CANT_BANYOS > 1
  AND a.SUPERFICIE >= 80
  AND u.DIST_METRO > 1
  AND u.DIST_CENTRO > 2
  AND p.PRECIO_ALQUILER BETWEEN 1500 AND 2000
  AND p.PORCENTAJE_RESERVA = 25
  AND pt.PUNTOS > 4.5
  AND pt.PUNTOS_AGENCIA > 4
ORDER BY a.CANT_HAB DESC, a.SUPERFICIE DESC
"""

pd.read_sql(query_final, conn)
# Out:
#   CODIGO_ALOJAMIENTO                 NOMBRE  CANT_HAB  CANT_BANYOS  \
# 0            ALOJ015       Dúplex Las Rocas         4            3
# 1            ALOJ018    Piso Parque Central         4            2
# 2            ALOJ004  Piso Centro Histórico         3            2
# 3            ALOJ010          Ático del Sol         3            3
#
#    SUPERFICIE TERRAZA AIREC_ACOND PISCINA SALON     PAIS    CIUDAD  \
# 0         120      SI          SI      NO    SI   España    Málaga
# 1         100      SI          SI      NO    SI   España     Ibiza
# 2          90      SI          SI      NO    SI  Francia  Marsella
# 3          88      SI          SI      NO    SI   España    Bilbao
#
#    DIST_METRO  DIST_CENTRO  PRECIO_ALQUILER  PORCENTAJE_RESERVA  PUNTOS  \
# 0         2.0          4.0             1800                  25     4.9
# 1         2.0          4.0             1900                  25     4.7
# 2         3.0          4.0             1600                  25     4.6
# ...

# %% [markdown]
# <span style="color:#3498db"> **RECOMENDACIÓN** </span>

# %% [markdown]
# <span style="color:#3498db"> Nuestro cliente está a punto de tener unas vacaciones en família, tranquilas y cómodas. Debo tener en cuenta que son 8 personas, entre ellas 3 parejas y dos supuestos niños o tal vez adolescentes hermanos menores del cliente.
# Ésto es muy importante, debe haber **4 habitaciones** y además considero que debe ser el apartamento **más espacioso** de ellos.
# Es por eso que el apartamento con código de alojamiento ALOJ015 situado en Málaga es el que recomendaría. </span>

# %%
# ========== ALOJAMIENTO RECOMENDADO =========

query_= """
SELECT 
    a.CODIGO_ALOJAMIENTO,
    a.NOMBRE,
    a.CANT_HAB,
    a.SUPERFICIE,
    u.CIUDAD,
    u.PAIS,
    p.PRECIO_ALQUILER,
    pt.PUNTOS,
    pt.AGENCIA
FROM alojamiento a
JOIN ubicacion u ON a.CODIGO_ALOJAMIENTO = u.CODIGO_ALOJAMIENTO
JOIN precio p ON a.CODIGO_ALOJAMIENTO = p.CODIGO_ALOJAMIENTO
JOIN puntuacion pt ON a.CODIGO_ALOJAMIENTO = pt.CODIGO_ALOJAMIENTO
WHERE a.CODIGO_ALOJAMIENTO = 'ALOJ015'
"""

pd.read_sql(query_, conn)
# Out:
#   CODIGO_ALOJAMIENTO            NOMBRE  CANT_HAB  SUPERFICIE  CIUDAD    PAIS  \
# 0            ALOJ015  Dúplex Las Rocas         4         120  Málaga  España
#
#    PRECIO_ALQUILER  PUNTOS            AGENCIA
# 0             1800     4.9  EasyStay Valencia

# %% [markdown]
# <span style="background-color:#28a745; color:white; padding:2px 8px; border-radius:12px; font-size:12px;">COMPLETADO</span>

# %% [markdown]
# ## <span style="color:#3498db"> **2.EJERCICIOS SEGUNDA PARTE**

# %% [markdown]
# <span style="color:#3498db">Responde las siguientes preguntas (con su respectiva query)
# * ¿Cuál es la suma total de metros cuadrados de los alojamientos que tienen piscina?
# * ¿Cuál es el alojamiento con mayor superficie?
# * ¿Cuál es el alojamiento con menor superficie?
# * ¿Cuántos alojamientos tienen salón?
# * ¿Cuántos alojamientos tienen terraza?
# * ¿Cuántos alojamientos hay por cada país según nuestra tabla de UBICACIÓN?
# * ¿Cuál es el promedio de precios de alquiler de todos los alojamientos según la
# tabla PRECIO?
# * ¿Cuáles son las 3 agencias que tienen la mayor puntuación de agencia (campo a
# usar: PUNTOS_AGENCIA) según la tabla PUNTUACION?
# * Muestra los alojamientos (código y nombre) que: Contengan la palabra ‘Piso’ en su
# nombre o que tengan piscina y aire acondicionado, pero no pasen los 150 metros
# de superficie o que tengan más de un baño
# * Muestra una consulta que muestre el código de alojamiento, el nombre, el precio y
# una columna donde veamos el precio del alquiler con el símbolo del euro al final de
# cada importe, esta nueva columna se debe llama PRECIO_MODIF
# * Muestra una columna sobre la tabla PRECIO que se llame CATEGORIA_PRECIO y
# que indique la palabra ‘Bajo’ si el precio está entre 780 y 1000, ‘Medio’ si el precio
# está entre 1000 y 1700 y ‘Alto’ si es mayor a 1700</span>

# %% [markdown]
# ### <span style="color:#3498db">2.1 QUERY METROS CUADRADOS TOTALES

# %%
# Query 1: Suma total de metros cuadrados con piscina
query1 = "SELECT SUM(SUPERFICIE) FROM alojamiento WHERE PISCINA = 'SI'"

pd.read_sql(query1, conn)
# Out:
#    SUM(SUPERFICIE)
# 0            850.0

# %% [markdown]
# ### <span style="color:#3498db">2.2 QUERY ALOJAMIENTO MAYOR SUPERFICIE

# %%
# Query 2: Alojamiento con mayor superficie con order by desc y limit 1 me dará el que tenga mayor superfície
query2 = "SELECT * FROM alojamiento ORDER BY SUPERFICIE DESC LIMIT 1"

pd.read_sql(query2, conn)
# Out:
#   CODIGO_ALOJAMIENTO                 NOMBRE  CANT_BANYOS  CANT_HAB SALON  \
# 0            ALOJ017  Chalet Jardín Secreto            3         5    SI
#
#   TERRAZA AIREC_ACOND PISCINA  SUPERFICIE
# 0      SI          SI      SI         180

# %% [markdown]
# ### <span style="color:#3498db">2.3 QUERY ALOJAMIENTO CON MENOR SUPERFICIE

# %%
# Query 2: Alojamiento con mayor superficie con order by ASC y limit 1 me dará el que tenga menor superfície
query3 = "SELECT * FROM alojamiento ORDER BY SUPERFICIE ASC LIMIT 1"

pd.read_sql(query3, conn)
# Out:
#   CODIGO_ALOJAMIENTO          NOMBRE  CANT_BANYOS  CANT_HAB SALON TERRAZA  \
# 0            ALOJ016  Estudio Urbano            1         1    NO      NO
#
#   AIREC_ACOND PISCINA  SUPERFICIE
# 0          SI      NO          35

# %% [markdown]
# ### <span style="color:#3498db">2.4 QUERY CUÁNTOS ALOJAMIENTOS TIENEN SALÓN

# %%
# Query 4: Cuántos alojamientos tienen salón
query4 = "SELECT COUNT(*) FROM alojamiento WHERE SALON = 'SI'"

pd.read_sql(query4, conn)
# Out:
#    COUNT(*)
# 0        16

# %% [markdown]
# ### <span style="color:#3498db">2.5 QUERY CUÁNTOS ALOJAMIENTOS TIENEN TERRAZA

# %%
# Query 5: Cuántos alojamientos tienen TERRAZA
query5 = "SELECT COUNT(*) FROM alojamiento WHERE TERRAZA = 'SI'"

pd.read_sql(query5, conn)
# Out:
#    COUNT(*)
# 0        14

# %% [markdown]
# ### <span style="color:#3498db">2.6 QUERY CUÁNTOS ALOJAMIENTOS POR PAÍS

# %%
# Query 6: Cuántos alojamientos por país
query6 = "SELECT PAIS, COUNT(*) FROM ubicacion GROUP BY PAIS"

pd.read_sql(query6, conn)
# Out:
#        PAIS  COUNT(*)
# 0  Portugal         4
# 1    España         8
# 2   Francia         4
# 3    Italia         4

# %% [markdown]
# ### <span style="color:#3498db">2.7 QUERY PRECIO PROMEDIO

# %%
# Query 7: Promedio de precios de alquiler
query7 = "SELECT AVG(PRECIO_ALQUILER) FROM precio"

pd.read_sql(query7, conn)
# Out:
#    AVG(PRECIO_ALQUILER)
# 0                1568.4

# %% [markdown]
# ### <span style="color:#3498db">2.8 QUERY AGENCIAS TOP3

# %%
# Query 8: Las 3 agencias con mayor puntuación
query8 = "SELECT * FROM puntuacion ORDER BY PUNTOS_AGENCIA DESC LIMIT 3"

pd.read_sql(query8, conn)
# Out:
#   CODIGO_ALOJAMIENTO  PUNTOS        AGENCIA  PUNTOS_AGENCIA
# 0            ALOJ006     4.3     TerraHouse             4.9
# 1            ALOJ010     4.8      UYAlquila             4.9
# 2            ALOJ011     4.0  MalagaTurismo             4.9

# %% [markdown]
# ### <span style="color:#3498db">2.9 QUERY CON OR  Y AND ("PISO" O PISCINA Y A/C, <150m o >1 wc)

# %%
# Query 9: Tres condiciones separadas
query9 = """SELECT CODIGO_ALOJAMIENTO, NOMBRE 
FROM alojamiento 
WHERE NOMBRE LIKE '%Piso%' 
   OR (PISCINA = 'SI' AND AIREC_ACOND = 'SI' AND SUPERFICIE < 150)
   OR (SUPERFICIE >= 150 AND CANT_BANYOS > 1)"""

pd.read_sql(query9, conn)
# Out:
#   CODIGO_ALOJAMIENTO                   NOMBRE
# 0            ALOJ001        Villa Sol del Mar
# 1            ALOJ004    Piso Centro Histórico
# 2            ALOJ006     Chalet Vista al Lago
# 3            ALOJ007  Dúplex Jardines del Sur
# 4            ALOJ012           Villa Palmeras
# 5            ALOJ014             Casa del Mar
# 6            ALOJ017    Chalet Jardín Secreto
# 7            ALOJ018      Piso Parque Central

# %%
# Query 9: Alojamientos que cumplan cualquiera de las 4 
query9 = """SELECT CODIGO_ALOJAMIENTO, NOMBRE 
FROM alojamiento 
WHERE NOMBRE LIKE '%Piso%' 
   OR (PISCINA = 'SI' AND AIREC_ACOND = 'SI' AND SUPERFICIE < 150) 
   OR CANT_BANYOS > 1"""

pd.read_sql(query9, conn)
# Out:
#    CODIGO_ALOJAMIENTO                   NOMBRE
# 0             ALOJ001        Villa Sol del Mar
# 1             ALOJ004    Piso Centro Histórico
# 2             ALOJ006     Chalet Vista al Lago
# 3             ALOJ007  Dúplex Jardines del Sur
# 4             ALOJ009     Casa Rústica Montaña
# 5             ALOJ010            Ático del Sol
# 6             ALOJ012           Villa Palmeras
# 7             ALOJ014             Casa del Mar
# 8             ALOJ015         Dúplex Las Rocas
# 9             ALOJ017    Chalet Jardín Secreto
# 10            ALOJ018      Piso Parque Central
# 11            ALOJ019           Casa Río Claro

# %% [markdown]
# Este enunciado tiene 4 condiciones. Pero cada dos condiciones se cancela con un OR, es decir finalmente tiene que cumplir una condicioón de cada par. Devolverá:
# - Si es PISO <150m
# - Si es PISO > 1 wc.
# - Si tiene piscina+AC, <150m
# - Si tiene piscina+AC, >1wc.

# %%
# Query 9b: Dos grupos combinados correctamente a mi parecer esta es la query que haría para el resultado que intuyo busca en el enunciado
query9b = """SELECT CODIGO_ALOJAMIENTO, NOMBRE 
FROM alojamiento 
WHERE (NOMBRE LIKE '%Piso%' AND (SUPERFICIE < 150 OR CANT_BANYOS > 1))
   OR (PISCINA = 'SI' AND AIREC_ACOND = 'SI' AND (SUPERFICIE < 150 OR CANT_BANYOS > 1))"""

pd.read_sql(query9b, conn)
# Out:
#   CODIGO_ALOJAMIENTO                   NOMBRE
# 0            ALOJ001        Villa Sol del Mar
# 1            ALOJ004    Piso Centro Histórico
# 2            ALOJ006     Chalet Vista al Lago
# 3            ALOJ007  Dúplex Jardines del Sur
# 4            ALOJ012           Villa Palmeras
# 5            ALOJ014             Casa del Mar
# 6            ALOJ017    Chalet Jardín Secreto
# 7            ALOJ018      Piso Parque Central

# %% [markdown]
# ### <span style="color:#3498db">2.10 NUEVA COLUMNA

# %%
# Query 10: Mostrar precio normal y precio con símbolo €
query10 = """SELECT 
    a.CODIGO_ALOJAMIENTO,
    a.NOMBRE,
    p.PRECIO_ALQUILER,
    CONCAT(p.PRECIO_ALQUILER, '€') as PRECIO_MODIF
FROM alojamiento a
JOIN precio p ON a.CODIGO_ALOJAMIENTO = p.CODIGO_ALOJAMIENTO"""

pd.read_sql(query10, conn)
# Out:
#    CODIGO_ALOJAMIENTO                    NOMBRE  PRECIO_ALQUILER PRECIO_MODIF
# 0             ALOJ001         Villa Sol del Mar             1800        1800€
# 1             ALOJ002  Apartamento Las Palmeras              780         780€
# 2             ALOJ003         Cabaña El Refugio              800         800€
# 3             ALOJ004     Piso Centro Histórico             1600        1600€
# 4             ALOJ005      Estudio Playa Blanca              900         900€
# 5             ALOJ006      Chalet Vista al Lago             1200        1200€
# 6             ALOJ007   Dúplex Jardines del Sur             1300        1300€
# 7             ALOJ008               Loft Urbano             1500        1500€
# 8             ALOJ009      Casa Rústica Montaña             1600        1600€
# 9             ALOJ010             Ático del Sol             1750        1750€
# 10            ALOJ011   Cabaña Bosque Encantado             1825        1825€
# ...

# %% [markdown]
# ### <span style="color:#3498db">2.11 CATEGORIA PRECIO

# %%
# Query 11: Columna CATEGORIA_PRECIO con categorías según rangos
query11 = """SELECT 
    CODIGO_ALOJAMIENTO,
    PRECIO_ALQUILER,
    RESERVA,
    PORCENTAJE_RESERVA,
    CASE 
        WHEN PRECIO_ALQUILER BETWEEN 780 AND 1000 THEN 'Bajo'
        WHEN PRECIO_ALQUILER BETWEEN 1001 AND 1700 THEN 'Medio' 
        WHEN PRECIO_ALQUILER > 1700 THEN 'Alto'
        ELSE 'Sin categoría'
    END AS CATEGORIA_PRECIO
FROM precio
ORDER BY PRECIO_ALQUILER"""

pd.read_sql(query11, conn)
# Out:
#    CODIGO_ALOJAMIENTO  PRECIO_ALQUILER RESERVA  PORCENTAJE_RESERVA  \
# 0             ALOJ002              780      SI                  25
# 1             ALOJ003              800      NO                   0
# 2             ALOJ005              900      NO                   0
# 3             ALOJ006             1200      NO                   0
# 4             ALOJ007             1300      NO                   0
# 5             ALOJ008             1500      SI                  25
# 6             ALOJ019             1570      NO                   0
# 7             ALOJ020             1580      NO                   0
# 8             ALOJ004             1600      SI                  25
# 9             ALOJ009             1600      SI                 100
# 10            ALOJ013             1652      NO                   0
# 11            ALOJ010             1750      SI                  25
# 12            ALOJ012             1750      NO                   0
# ...

# %% [markdown]
# <div style="background-color:#d4edda; padding:10px; border-left:4px solid #28a745; margin:10px 0; color:#2c3e50;">
# <strong>✅ Éxito:</strong> Operación completada
# </div>

# %% [markdown]
# <div align="center">
# <h2>FIN DEL ENTREGABLE</h2>
# <p>Junio 2025</p>
# </div>
